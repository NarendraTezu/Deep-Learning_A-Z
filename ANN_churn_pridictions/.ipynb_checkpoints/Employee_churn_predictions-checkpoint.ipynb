# %% [markdown]
# ## Artificial Neural Network

# %% [markdown]
# #### Part 1 - Data Preprocessing

# %%
# Import the library 

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
# loading dataset 

dataset = pd.read_csv("Churn_Modelling.csv")

# %%
dataset
# Out:
#       RowNumber  CustomerId    Surname  CreditScore Geography  Gender  Age  \
# 0             1    15634602   Hargrave          619    France  Female   42
# 1             2    15647311       Hill          608     Spain  Female   41
# 2             3    15619304       Onio          502    France  Female   42
# 3             4    15701354       Boni          699    France  Female   39
# 4             5    15737888   Mitchell          850     Spain  Female   43
# ...         ...         ...        ...          ...       ...     ...  ...
# 9995       9996    15606229   Obijiaku          771    France    Male   39
# 9996       9997    15569892  Johnstone          516    France    Male   35
# 9997       9998    15584532        Liu          709    France  Female   36
# 9998       9999    15682355  Sabbatini          772   Germany    Male   42
# 9999      10000    15628319     Walker          792    France  Female   28
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0          2       0.00              1          1               1
# 1          1   83807.86              1          0               1
# 2          8  159660.80              3          1               0
# 3          1       0.00              2          0               0
# 4          2  125510.82              1          1               1
# ...      ...        ...            ...        ...             ...
# 9995       5       0.00              2          1               0
# 9996      10   57369.61              1          1               1
# 9997       7       0.00              1          0               1
# 9998       3   75075.31              2          1               0
# 9999       4  130142.79              1          1               0
#
#       EstimatedSalary  Exited
# 0           101348.88       1
# 1           112542.58       0
# 2           113931.57       1
# 3            93826.63       0
# 4            79084.10       0
# ...               ...     ...
# 9995         96270.64       0
# 9996        101699.77       0
# 9997         42085.58       1
# 9998         92888.52       1
# 9999         38190.78       0
#
# [10000 rows x 14 columns]

# %%
X = dataset.iloc[:, 3:13]
y = dataset.iloc[:,13]

# %%
# Create dummy variable for categorical feature

geography = pd.get_dummies(X["Geography"],drop_first=True)
gender = pd.get_dummies(X["Gender"],drop_first=True)

# %%
# mearging created dummy column to our feature dataframe x

X = pd.concat([X,geography,gender], axis=1)

# %%
# drop unwanted column 

X = X.drop(["Geography","Gender"],axis=1)

# %%
# importing train test split library
from sklearn.model_selection import train_test_split

# %%
# spliting the dataset into their traning set and test set

x_train, x_test, y_train, y_test = train_test_split(X,y, test_size=0.2, random_state=2)

# %%
# import feature scalling library

from sklearn.preprocessing import StandardScaler

# %%
sc = StandardScaler()
x_train = sc.fit_transform(x_train)
x_test = sc.fit_transform(x_test)

# %% [markdown]
# #### Part 2 - Make ANN

# %%
import keras
from keras.models import Sequential
from keras.layers import Dense
# from keras.layers import LeakyReLU, PReLU, ELU
from keras.layers import Dropout

# %%
# initialising the ANN

classifier = Sequential()

# %%
# Adding the input and first hidden layer
classifier.add(Dense(units=6, kernel_initializer='he_uniform', activation='relu', input_dim=11))

# %%
# Adding the input and first hidden layer
classifier.add(Dense(units=6, kernel_initializer='he_uniform', activation='relu', input_dim=11))

# %%
# Adding the input and first hidden layer
classifier.add(Dense(units=1, kernel_initializer='glorot_uniform', activation='sigmoid'))

# %%
classifier.compile(optimizer = "adam", loss = "binary_crossentropy", metrics = ["accuracy"])

# %%
# fitting the ANN to the traning set 

model_history = classifier.fit(x_train, y_train, validation_split=0.33, batch_size=10, epochs=100)
# Out:
# Epoch 1/100
# 536/536 [==============================] - 2s 3ms/step - loss: 0.5736 - accuracy: 0.7572 - val_loss: 0.4992 - val_accuracy: 0.7989
# Epoch 2/100
# 536/536 [==============================] - 1s 2ms/step - loss: 0.4919 - accuracy: 0.7876 - val_loss: 0.4604 - val_accuracy: 0.8031
# Epoch 3/100
# 536/536 [==============================] - 1s 2ms/step - loss: 0.4602 - accuracy: 0.7899 - val_loss: 0.4357 - val_accuracy: 0.8065
# Epoch 4/100
# 536/536 [==============================] - 1s 2ms/step - loss: 0.4406 - accuracy: 0.7966 - val_loss: 0.4197 - val_accuracy: 0.8129
# Epoch 5/100
# 536/536 [==============================] - 1s 3ms/step - loss: 0.4255 - accuracy: 0.8039 - val_loss: 0.4044 - val_accuracy: 0.8201
# Epoch 6/100
# 536/536 [==============================] - 1s 2ms/step - loss: 0.4111 - accuracy: 0.8128 - val_loss: 0.3939 - val_accuracy: 0.8262
# Epoch 7/100
# 536/536 [==============================] - 1s 2ms/step - loss: 0.4018 - accuracy: 0.8199 - val_loss: 0.3872 - val_accuracy: 0.8254
# Epoch 8/100
# 536/536 [==============================] - 1s 2ms/step - loss: 0.3961 - accuracy: 0.8220 - val_loss: 0.3825 - val_accuracy: 0.8270
# Epoch 9/100
# 536/536 [==============================] - 1s 2ms/step - loss: 0.3920 - accuracy: 0.8242 - val_loss: 0.3788 - val_accuracy: 0.8342
# Epoch 10/100
# 536/536 [==============================] - 1s 2ms/step - loss: 0.3890 - accuracy: 0.8259 - val_loss: 0.3764 - val_accuracy: 0.8353
# Epoch 11/100
# 536/536 [==============================] - 1s 2ms/step - loss: 0.3862 - accuracy: 0.8268 - val_loss: 0.3747 - val_accuracy: 0.8372
# Epoch 12/100
# 536/536 [==============================] - 1s 2ms/step - loss: 0.3837 - accuracy: 0.8268 - val_loss: 0.3714 - val_accuracy: 0.8383
# Epoch 13/100
# 536/536 [==============================] - 1s 2ms/step - loss: 0.3813 - accuracy: 0.8278 - val_loss: 0.3694 - val_accuracy: 0.8402
# Epoch 14/100
# 536/536 [==============================] - 1s 3ms/step - loss: 0.3791 - accuracy: 0.8285 - val_loss: 0.3676 - val_accuracy: 0.8391
# Epoch 15/100
# 536/536 [==============================] - 1s 2ms/step - loss: 0.3770 - accuracy: 0.8293 - val_loss: 0.3660 - val_accuracy: 0.8395
# Epoch 16/100
# 536/536 [==============================] - 1s 2ms/step - loss: 0.3749 - accuracy: 0.8309 - val_loss: 0.3635 - val_accuracy: 0.8398
# Epoch 17/100
# 536/536 [==============================] - 1s 2ms/step - loss: 0.3729 - accuracy: 0.8306 - val_loss: 0.3619 - val_accuracy: 0.8398
# Epoch 18/100
# 536/536 [==============================] - 1s 2ms/step - loss: 0.3709 - accuracy: 0.8328 - val_loss: 0.3597 - val_accuracy: 0.8406
# Epoch 19/100
# 536/536 [==============================] - 1s 2ms/step - loss: 0.3678 - accuracy: 0.8322 - val_loss: 0.3563 - val_accuracy: 0.8417
# Epoch 20/100
# 536/536 [==============================] - 1s 2ms/step - loss: 0.3632 - accuracy: 0.8375 - val_loss: 0.3521 - val_accuracy: 0.8531
# Epoch 21/100
# 536/536 [==============================] - 1s 2ms/step - loss: 0.3592 - accuracy: 0.8414 - val_loss: 0.3472 - val_accuracy: 0.8603
# Epoch 22/100
# 536/536 [==============================] - 1s 2ms/step - loss: 0.3544 - accuracy: 0.8483 - val_loss: 0.3431 - val_accuracy: 0.8637
# Epoch 23/100
# 536/536 [==============================] - 1s 3ms/step - loss: 0.3500 - accuracy: 0.8492 - val_loss: 0.3376 - val_accuracy: 0.8671
# Epoch 24/100
# 536/536 [==============================] - 1s 2ms/step - loss: 0.3463 - accuracy: 0.8548 - val_loss: 0.3361 - val_accuracy: 0.8671
# Epoch 25/100
# 536/536 [==============================] - 1s 2ms/step - loss: 0.3451 - accuracy: 0.8537 - val_loss: 0.3356 - val_accuracy: 0.8660
# Epoch 26/100
# 536/536 [==============================] - 1s 2ms/step - loss: 0.3429 - accuracy: 0.8563 - val_loss: 0.3346 - val_accuracy: 0.8660
# Epoch 27/100
# 536/536 [==============================] - 1s 2ms/step - loss: 0.3419 - accuracy: 0.8569 - val_loss: 0.3331 - val_accuracy: 0.8671
# Epoch 28/100
# 536/536 [==============================] - 1s 2ms/step - loss: 0.3414 - accuracy: 0.8559 - val_loss: 0.3315 - val_accuracy: 0.8660
# Epoch 29/100
# 536/536 [==============================] - 1s 2ms/step - loss: 0.3402 - accuracy: 0.8584 - val_loss: 0.3316 - val_accuracy: 0.8694
# Epoch 30/100
# 536/536 [==============================] - 1s 2ms/step - loss: 0.3393 - accuracy: 0.8563 - val_loss: 0.3308 - val_accuracy: 0.8682
# Epoch 31/100
# 536/536 [==============================] - 1s 2ms/step - loss: 0.3392 - accuracy: 0.8576 - val_loss: 0.3312 - val_accuracy: 0.8686
# Epoch 32/100
# 536/536 [==============================] - 1s 2ms/step - loss: 0.3388 - accuracy: 0.8582 - val_loss: 0.3290 - val_accuracy: 0.8679
# Epoch 33/100
# 536/536 [==============================] - 1s 2ms/step - loss: 0.3383 - accuracy: 0.8574 - val_loss: 0.3311 - val_accuracy: 0.8671
# Epoch 34/100
# 536/536 [==============================] - 1s 2ms/step - loss: 0.3383 - accuracy: 0.8584 - val_loss: 0.3307 - val_accuracy: 0.8709
# Epoch 35/100
# 536/536 [==============================] - 1s 2ms/step - loss: 0.3380 - accuracy: 0.8584 - val_loss: 0.3334 - val_accuracy: 0.8686
# Epoch 36/100
# 536/536 [==============================] - 1s 2ms/step - loss: 0.3380 - accuracy: 0.8578 - val_loss: 0.3299 - val_accuracy: 0.8697
# Epoch 37/100
# 536/536 [==============================] - 1s 2ms/step - loss: 0.3376 - accuracy: 0.8584 - val_loss: 0.3309 - val_accuracy: 0.8671
# Epoch 38/100
# 536/536 [==============================] - 1s 2ms/step - loss: 0.3370 - accuracy: 0.8600 - val_loss: 0.3294 - val_accuracy: 0.8701
# Epoch 39/100
# 536/536 [==============================] - 1s 2ms/step - loss: 0.3376 - accuracy: 0.8586 - val_loss: 0.3299 - val_accuracy: 0.8709
# Epoch 40/100
# 536/536 [==============================] - 1s 2ms/step - loss: 0.3371 - accuracy: 0.8565 - val_loss: 0.3294 - val_accuracy: 0.8720
# Epoch 41/100
# 536/536 [==============================] - 1s 2ms/step - loss: 0.3379 - accuracy: 0.8587 - val_loss: 0.3288 - val_accuracy: 0.8690
# Epoch 42/100
# 536/536 [==============================] - 1s 2ms/step - loss: 0.3372 - accuracy: 0.8595 - val_loss: 0.3297 - val_accuracy: 0.8705
# Epoch 43/100
# 536/536 [==============================] - 1s 2ms/step - loss: 0.3367 - accuracy: 0.8599 - val_loss: 0.3307 - val_accuracy: 0.8694
# Epoch 44/100
# 536/536 [==============================] - 1s 2ms/step - loss: 0.3366 - accuracy: 0.8569 - val_loss: 0.3308 - val_accuracy: 0.8682
# Epoch 45/100
# 536/536 [==============================] - 1s 2ms/step - loss: 0.3367 - accuracy: 0.8576 - val_loss: 0.3292 - val_accuracy: 0.8705
# Epoch 46/100
# 536/536 [==============================] - 1s 2ms/step - loss: 0.3354 - accuracy: 0.8602 - val_loss: 0.3283 - val_accuracy: 0.8713
# Epoch 47/100
# 536/536 [==============================] - 1s 2ms/step - loss: 0.3364 - accuracy: 0.8600 - val_loss: 0.3291 - val_accuracy: 0.8713
# Epoch 48/100
# 536/536 [==============================] - 1s 2ms/step - loss: 0.3360 - accuracy: 0.8584 - val_loss: 0.3296 - val_accuracy: 0.8709
# Epoch 49/100
# 536/536 [==============================] - 1s 2ms/step - loss: 0.3355 - accuracy: 0.8606 - val_loss: 0.3319 - val_accuracy: 0.8697
# Epoch 50/100
# 536/536 [==============================] - 1s 2ms/step - loss: 0.3360 - accuracy: 0.8586 - val_loss: 0.3294 - val_accuracy: 0.8713
# Epoch 51/100
# 536/536 [==============================] - 1s 2ms/step - loss: 0.3357 - accuracy: 0.8593 - val_loss: 0.3297 - val_accuracy: 0.8694
# Epoch 52/100
# 536/536 [==============================] - 1s 2ms/step - loss: 0.3360 - accuracy: 0.8593 - val_loss: 0.3289 - val_accuracy: 0.8686
# Epoch 53/100
# 536/536 [==============================] - 1s 2ms/step - loss: 0.3354 - accuracy: 0.8578 - val_loss: 0.3301 - val_accuracy: 0.8694
# Epoch 54/100
# 536/536 [==============================] - 1s 2ms/step - loss: 0.3353 - accuracy: 0.8612 - val_loss: 0.3291 - val_accuracy: 0.8713
# Epoch 55/100
# 536/536 [==============================] - 1s 2ms/step - loss: 0.3354 - accuracy: 0.8600 - val_loss: 0.3288 - val_accuracy: 0.8716
# Epoch 56/100
# 536/536 [==============================] - 1s 2ms/step - loss: 0.3353 - accuracy: 0.8597 - val_loss: 0.3291 - val_accuracy: 0.8686
# Epoch 57/100
# 536/536 [==============================] - 1s 2ms/step - loss: 0.3352 - accuracy: 0.8589 - val_loss: 0.3292 - val_accuracy: 0.8697
# Epoch 58/100
# 536/536 [==============================] - 1s 2ms/step - loss: 0.3347 - accuracy: 0.8599 - val_loss: 0.3318 - val_accuracy: 0.8679
# Epoch 59/100
# 536/536 [==============================] - 1s 2ms/step - loss: 0.3347 - accuracy: 0.8597 - val_loss: 0.3287 - val_accuracy: 0.8705
# Epoch 60/100
# 536/536 [==============================] - 1s 2ms/step - loss: 0.3350 - accuracy: 0.8587 - val_loss: 0.3300 - val_accuracy: 0.8690
# Epoch 61/100
# 536/536 [==============================] - 1s 2ms/step - loss: 0.3350 - accuracy: 0.8627 - val_loss: 0.3298 - val_accuracy: 0.8713
# Epoch 62/100
# 536/536 [==============================] - 1s 2ms/step - loss: 0.3346 - accuracy: 0.8602 - val_loss: 0.3299 - val_accuracy: 0.8694
# Epoch 63/100
# 536/536 [==============================] - 1s 2ms/step - loss: 0.3346 - accuracy: 0.8589 - val_loss: 0.3285 - val_accuracy: 0.8716
# Epoch 64/100
# 536/536 [==============================] - 1s 2ms/step - loss: 0.3347 - accuracy: 0.8636 - val_loss: 0.3300 - val_accuracy: 0.8697
# Epoch 65/100
# 536/536 [==============================] - 1s 2ms/step - loss: 0.3348 - accuracy: 0.8589 - val_loss: 0.3281 - val_accuracy: 0.8701
# Epoch 66/100
# 536/536 [==============================] - 1s 2ms/step - loss: 0.3344 - accuracy: 0.8610 - val_loss: 0.3322 - val_accuracy: 0.8671
# Epoch 67/100
# 536/536 [==============================] - 1s 2ms/step - loss: 0.3339 - accuracy: 0.8582 - val_loss: 0.3305 - val_accuracy: 0.8686
# Epoch 68/100
# 536/536 [==============================] - 1s 2ms/step - loss: 0.3346 - accuracy: 0.8606 - val_loss: 0.3301 - val_accuracy: 0.8686
# Epoch 69/100
# 536/536 [==============================] - 1s 2ms/step - loss: 0.3343 - accuracy: 0.8580 - val_loss: 0.3298 - val_accuracy: 0.8671
# Epoch 70/100
# 536/536 [==============================] - 1s 2ms/step - loss: 0.3349 - accuracy: 0.8584 - val_loss: 0.3300 - val_accuracy: 0.8690
# Epoch 71/100
# 536/536 [==============================] - 1s 2ms/step - loss: 0.3344 - accuracy: 0.8595 - val_loss: 0.3318 - val_accuracy: 0.8679
# Epoch 72/100
# 536/536 [==============================] - 1s 2ms/step - loss: 0.3338 - accuracy: 0.8614 - val_loss: 0.3295 - val_accuracy: 0.8682
# Epoch 73/100
# 536/536 [==============================] - 1s 2ms/step - loss: 0.3344 - accuracy: 0.8602 - val_loss: 0.3280 - val_accuracy: 0.8701
# Epoch 74/100
# 536/536 [==============================] - 1s 2ms/step - loss: 0.3339 - accuracy: 0.8606 - val_loss: 0.3318 - val_accuracy: 0.8682
# Epoch 75/100
# 536/536 [==============================] - 1s 2ms/step - loss: 0.3340 - accuracy: 0.8614 - val_loss: 0.3296 - val_accuracy: 0.8679
# Epoch 76/100
# 536/536 [==============================] - 1s 2ms/step - loss: 0.3340 - accuracy: 0.8591 - val_loss: 0.3283 - val_accuracy: 0.8679
# Epoch 77/100
# 536/536 [==============================] - 1s 2ms/step - loss: 0.3335 - accuracy: 0.8619 - val_loss: 0.3319 - val_accuracy: 0.8682
# Epoch 78/100
# 536/536 [==============================] - 1s 2ms/step - loss: 0.3344 - accuracy: 0.8606 - val_loss: 0.3299 - val_accuracy: 0.8709
# Epoch 79/100
# 536/536 [==============================] - 1s 2ms/step - loss: 0.3338 - accuracy: 0.8610 - val_loss: 0.3287 - val_accuracy: 0.8705
# Epoch 80/100
# 536/536 [==============================] - 1s 2ms/step - loss: 0.3336 - accuracy: 0.8621 - val_loss: 0.3296 - val_accuracy: 0.8697
# Epoch 81/100
# 536/536 [==============================] - 1s 2ms/step - loss: 0.3336 - accuracy: 0.8600 - val_loss: 0.3303 - val_accuracy: 0.8701
# Epoch 82/100
# 536/536 [==============================] - 1s 2ms/step - loss: 0.3339 - accuracy: 0.8612 - val_loss: 0.3338 - val_accuracy: 0.8671
# Epoch 83/100
# 536/536 [==============================] - 1s 2ms/step - loss: 0.3339 - accuracy: 0.8591 - val_loss: 0.3290 - val_accuracy: 0.8709
# Epoch 84/100
# 536/536 [==============================] - 1s 2ms/step - loss: 0.3334 - accuracy: 0.8610 - val_loss: 0.3321 - val_accuracy: 0.8679
# Epoch 85/100
# 536/536 [==============================] - 1s 2ms/step - loss: 0.3335 - accuracy: 0.8602 - val_loss: 0.3290 - val_accuracy: 0.8705
# Epoch 86/100
# 536/536 [==============================] - 1s 2ms/step - loss: 0.3342 - accuracy: 0.8621 - val_loss: 0.3295 - val_accuracy: 0.8716
# Epoch 87/100
# 536/536 [==============================] - 1s 2ms/step - loss: 0.3330 - accuracy: 0.8619 - val_loss: 0.3298 - val_accuracy: 0.8716
# Epoch 88/100
# 536/536 [==============================] - 1s 2ms/step - loss: 0.3335 - accuracy: 0.8610 - val_loss: 0.3296 - val_accuracy: 0.8716
# Epoch 89/100
# 536/536 [==============================] - 1s 2ms/step - loss: 0.3339 - accuracy: 0.8602 - val_loss: 0.3304 - val_accuracy: 0.8701
# Epoch 90/100
# 536/536 [==============================] - 1s 2ms/step - loss: 0.3334 - accuracy: 0.8602 - val_loss: 0.3309 - val_accuracy: 0.8709
# Epoch 91/100
# 536/536 [==============================] - 1s 2ms/step - loss: 0.3336 - accuracy: 0.8617 - val_loss: 0.3295 - val_accuracy: 0.8709
# Epoch 92/100
# 536/536 [==============================] - 1s 2ms/step - loss: 0.3331 - accuracy: 0.8614 - val_loss: 0.3289 - val_accuracy: 0.8716
# Epoch 93/100
# 536/536 [==============================] - 1s 2ms/step - loss: 0.3331 - accuracy: 0.8589 - val_loss: 0.3298 - val_accuracy: 0.8713
# Epoch 94/100
# 536/536 [==============================] - 1s 2ms/step - loss: 0.3335 - accuracy: 0.8604 - val_loss: 0.3313 - val_accuracy: 0.8697
# Epoch 95/100
# 536/536 [==============================] - 1s 2ms/step - loss: 0.3341 - accuracy: 0.8597 - val_loss: 0.3294 - val_accuracy: 0.8697
# Epoch 96/100
# 536/536 [==============================] - 1s 2ms/step - loss: 0.3333 - accuracy: 0.8599 - val_loss: 0.3303 - val_accuracy: 0.8682
# Epoch 97/100
# 536/536 [==============================] - 1s 2ms/step - loss: 0.3330 - accuracy: 0.8595 - val_loss: 0.3307 - val_accuracy: 0.8694
# Epoch 98/100
# 536/536 [==============================] - 1s 2ms/step - loss: 0.3333 - accuracy: 0.8600 - val_loss: 0.3297 - val_accuracy: 0.8697
# Epoch 99/100
# 536/536 [==============================] - 1s 2ms/step - loss: 0.3333 - accuracy: 0.8619 - val_loss: 0.3298 - val_accuracy: 0.8701
# Epoch 100/100
# 536/536 [==============================] - 1s 2ms/step - loss: 0.3337 - accuracy: 0.8604 - val_loss: 0.3296 - val_accuracy: 0.8697

# %%
# Printing the all data history 
print(model_history.history.keys())
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %%
# Summrize the history for loss

plt.plot(model_history.history["loss"])
plt.plot(model_history.history["val_loss"])
plt.title("model loss")
plt.ylabel("loss")
plt.xlabel("epoch")
plt.legend(["train", "test"], loc="upper left")
plt.show()

# %% [markdown]
# #### Part 3 - Predictions and evaluating the model

# %%
# Predicting the result on test data

y_pred = classifier.predict(x_test)
y_pred = (y_pred > 0.5)
# Out:
# 63/63 [==============================] - 0s 1ms/step

# %%
# making the confusion matrix 

from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test, y_pred)

# %%
# calculate the accuraccy 

from sklearn.metrics import accuracy_score
score = accuracy_score(y_pred, y_test)
