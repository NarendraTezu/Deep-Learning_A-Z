# %% [markdown]
# #### Keras Tuner- Decide Number of Hidden Layers And Neuron In Neural Network

# %%
#!pip install keras-tuner --upgrade

# %%
import pandas as pd
from tensorflow import keras
from tensorflow.keras import layers
from kerastuner.tuners import RandomSearch

# %%
df=pd.read_csv('Real_Combine.csv')

# %%
df.head()
# Out:
#       T    TM   Tm     SLP     H   VV    V    VM      PM 2.5
# 0   7.4   9.8  4.8  1017.6  93.0  0.5  4.3   9.4  219.720833
# 1   7.8  12.7  4.4  1018.5  87.0  0.6  4.4  11.1  182.187500
# 2   6.7  13.4  2.4  1019.4  82.0  0.6  4.8  11.1  154.037500
# 3   8.6  15.5  3.3  1018.7  72.0  0.8  8.1  20.6  223.208333
# 4  12.4  20.9  4.4  1017.3  61.0  1.3  8.7  22.2  200.645833

# %%
df = df.dropna()

# %%
X=df.iloc[:,:-1] ## independent features
y=df.iloc[:,-1] ## dependent features

# %% [markdown]
# #### Hyperparameters
# 1. How many number of hidden layers we should have?
# 2. How many number of neurons we should have in hidden layers?
# 3. Learning Rate

# %%
def build_model(hp):
    model = keras.Sequential()
    for i in range(hp.Int('num_layers', 2, 20)):
        model.add(layers.Dense(units=hp.Int('units_' + str(i),
                                            min_value=32,
                                            max_value=512,
                                            step=32),
                               activation='relu'))
    model.add(layers.Dense(1, activation='linear'))
    model.compile(
        optimizer=keras.optimizers.Adam(
            hp.Choice('learning_rate', [1e-2, 1e-3, 1e-4])),
        loss='mean_absolute_error',
        metrics=['mean_absolute_error'])
    return model

# %%
tuner = RandomSearch(
    build_model,
    objective='val_mean_absolute_error',
    max_trials=20,
    executions_per_trial=3,
    directory='project',
    project_name='Air Quality Index')
# Out:
# INFO:tensorflow:Reloading Tuner from project/Air Quality Index/tuner0.json

# %%
tuner.search_space_summary()
# Out:
# Search space summary
# Default search space size: 22
# num_layers (Int)
# {'default': None, 'conditions': [], 'min_value': 2, 'max_value': 20, 'step': 1, 'sampling': 'linear'}
# units_0 (Int)
# {'default': None, 'conditions': [], 'min_value': 32, 'max_value': 512, 'step': 32, 'sampling': 'linear'}
# units_1 (Int)
# {'default': None, 'conditions': [], 'min_value': 32, 'max_value': 512, 'step': 32, 'sampling': 'linear'}
# learning_rate (Choice)
# {'default': 0.01, 'conditions': [], 'values': [0.01, 0.001, 0.0001], 'ordered': True}
# units_2 (Int)
# {'default': None, 'conditions': [], 'min_value': 32, 'max_value': 512, 'step': 32, 'sampling': 'linear'}
# units_3 (Int)
# {'default': None, 'conditions': [], 'min_value': 32, 'max_value': 512, 'step': 32, 'sampling': 'linear'}
# units_4 (Int)
# {'default': None, 'conditions': [], 'min_value': 32, 'max_value': 512, 'step': 32, 'sampling': 'linear'}
# units_5 (Int)
# {'default': None, 'conditions': [], 'min_value': 32, 'max_value': 512, 'step': 32, 'sampling': 'linear'}
# units_6 (Int)
# {'default': None, 'conditions': [], 'min_value': 32, 'max_value': 512, 'step': 32, 'sampling': 'linear'}
# units_7 (Int)
# {'default': None, 'conditions': [], 'min_value': 32, 'max_value': 512, 'step': 32, 'sampling': 'linear'}
# units_8 (Int)
# {'default': None, 'conditions': [], 'min_value': 32, 'max_value': 512, 'step': 32, 'sampling': 'linear'}
# units_9 (Int)
# {'default': None, 'conditions': [], 'min_value': 32, 'max_value': 512, 'step': 32, 'sampling': 'linear'}
# units_10 (Int)
# {'default': None, 'conditions': [], 'min_value': 32, 'max_value': 512, 'step': 32, 'sampling': 'linear'}
# units_11 (Int)
# {'default': None, 'conditions': [], 'min_value': 32, 'max_value': 512, 'step': 32, 'sampling': 'linear'}
# units_12 (Int)
# {'default': None, 'conditions': [], 'min_value': 32, 'max_value': 512, 'step': 32, 'sampling': 'linear'}
# units_13 (Int)
# {'default': None, 'conditions': [], 'min_value': 32, 'max_value': 512, 'step': 32, 'sampling': 'linear'}
# units_14 (Int)
# {'default': None, 'conditions': [], 'min_value': 32, 'max_value': 512, 'step': 32, 'sampling': 'linear'}
# units_15 (Int)
# {'default': None, 'conditions': [], 'min_value': 32, 'max_value': 512, 'step': 32, 'sampling': 'linear'}
# units_16 (Int)
# {'default': None, 'conditions': [], 'min_value': 32, 'max_value': 512, 'step': 32, 'sampling': 'linear'}
# units_17 (Int)
# {'default': None, 'conditions': [], 'min_value': 32, 'max_value': 512, 'step': 32, 'sampling': 'linear'}
# units_18 (Int)
# {'default': None, 'conditions': [], 'min_value': 32, 'max_value': 512, 'step': 32, 'sampling': 'linear'}
# units_19 (Int)
# {'default': None, 'conditions': [], 'min_value': 32, 'max_value': 512, 'step': 32, 'sampling': 'linear'}

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=0)

# %%
tuner.search(X_train, y_train,
             epochs=5,
             validation_data=(X_test, y_test))
# Out:
# Trial 20 Complete [00h 00m 09s]
# val_mean_absolute_error: 60.9184201558431
#
# Best val_mean_absolute_error So Far: 51.348907470703125
# Total elapsed time: 00h 01m 59s
# INFO:tensorflow:Oracle triggered exit

# %%
tuner.results_summary()
# Out:
# Results summary
# Results in project/Air Quality Index
# Showing 10 best trials
# Objective(name="val_mean_absolute_error", direction="min")
#
# Trial 15 summary
# Hyperparameters:
# num_layers: 13
# units_0: 480
# units_1: 416
# learning_rate: 0.01
# units_2: 512
# units_3: 480
# units_4: 416
# units_5: 32
# units_6: 512
# units_7: 96
# units_8: 160
# units_9: 32
# units_10: 448
# units_11: 416
# units_12: 480
# units_13: 32
# units_14: 256
# units_15: 448
# units_16: 256
# units_17: 192
# units_18: 320
# units_19: 512
# Score: 51.348907470703125
#
# Trial 12 summary
# Hyperparameters:
# num_layers: 2
# units_0: 448
# units_1: 64
# learning_rate: 0.01
# units_2: 96
# units_3: 480
# units_4: 128
# units_5: 96
# units_6: 416
# units_7: 256
# units_8: 256
# units_9: 384
# units_10: 352
# units_11: 64
# units_12: 352
# units_13: 448
# units_14: 192
# units_15: 160
# units_16: 128
# units_17: 288
# units_18: 256
# units_19: 256
# Score: 53.38873036702474
#
# Trial 10 summary
# Hyperparameters:
# num_layers: 14
# units_0: 352
# units_1: 352
# learning_rate: 0.01
# units_2: 256
# units_3: 448
# units_4: 448
# units_5: 384
# units_6: 64
# units_7: 256
# units_8: 160
# units_9: 224
# units_10: 224
# units_11: 320
# units_12: 256
# units_13: 128
# units_14: 64
# units_15: 128
# units_16: 64
# units_17: 288
# units_18: 352
# units_19: 224
# Score: 53.81443405151367
#
# Trial 11 summary
# Hyperparameters:
# num_layers: 13
# units_0: 224
# units_1: 192
# learning_rate: 0.01
# units_2: 448
# units_3: 288
# units_4: 384
# units_5: 128
# units_6: 416
# units_7: 352
# units_8: 192
# units_9: 448
# units_10: 128
# units_11: 416
# units_12: 128
# units_13: 384
# units_14: 384
# units_15: 384
# units_16: 160
# units_17: 128
# units_18: 384
# units_19: 192
# Score: 54.72677103678385
#
# Trial 07 summary
# Hyperparameters:
# num_layers: 5
# units_0: 512
# units_1: 224
# learning_rate: 0.001
# units_2: 512
# units_3: 352
# units_4: 192
# units_5: 384
# units_6: 128
# units_7: 512
# units_8: 448
# units_9: 256
# units_10: 64
# units_11: 480
# units_12: 320
# units_13: 384
# units_14: 416
# units_15: 448
# units_16: 224
# units_17: 320
# units_18: 256
# units_19: 192
# Score: 56.164015452067055
#
# Trial 08 summary
# Hyperparameters:
# num_layers: 2
# units_0: 160
# units_1: 96
# learning_rate: 0.001
# units_2: 416
# units_3: 416
# units_4: 224
# units_5: 480
# units_6: 320
# units_7: 448
# units_8: 320
# units_9: 480
# units_10: 224
# units_11: 96
# units_12: 256
# units_13: 448
# units_14: 96
# units_15: 320
# units_16: 256
# units_17: 256
# units_18: 224
# units_19: 192
# Score: 59.6302604675293
#
# Trial 18 summary
# Hyperparameters:
# num_layers: 15
# units_0: 128
# units_1: 384
# learning_rate: 0.01
# units_2: 224
# units_3: 160
# units_4: 352
# units_5: 416
# units_6: 320
# units_7: 192
# units_8: 128
# units_9: 448
# units_10: 320
# units_11: 448
# units_12: 448
# units_13: 320
# units_14: 192
# units_15: 128
# units_16: 320
# units_17: 320
# units_18: 192
# units_19: 256
# Score: 59.8926633199056
#
# Trial 14 summary
# Hyperparameters:
# num_layers: 6
# units_0: 512
# units_1: 352
# learning_rate: 0.001
# units_2: 416
# units_3: 416
# units_4: 96
# units_5: 96
# units_6: 288
# units_7: 480
# units_8: 64
# units_9: 224
# units_10: 64
# units_11: 384
# units_12: 128
# units_13: 352
# units_14: 160
# units_15: 224
# units_16: 512
# units_17: 224
# units_18: 480
# units_19: 128
# Score: 60.233709971110024
#
# Trial 19 summary
# Hyperparameters:
# num_layers: 14
# units_0: 32
# units_1: 128
# learning_rate: 0.01
# units_2: 416
# units_3: 32
# units_4: 288
# units_5: 64
# units_6: 416
# units_7: 32
# units_8: 288
# units_9: 224
# units_10: 320
# units_11: 352
# units_12: 480
# units_13: 64
# units_14: 224
# units_15: 128
# units_16: 160
# units_17: 512
# units_18: 512
# units_19: 320
# Score: 60.9184201558431
#
# Trial 16 summary
# Hyperparameters:
# num_layers: 4
# units_0: 128
# units_1: 224
# learning_rate: 0.001
# units_2: 448
# units_3: 384
# units_4: 192
# units_5: 96
# units_6: 160
# units_7: 512
# units_8: 512
# units_9: 384
# units_10: 64
# units_11: 96
# units_12: 32
# units_13: 160
# units_14: 160
# units_15: 32
# units_16: 448
# units_17: 256
# units_18: 512
# units_19: 384
# Score: 61.05499394734701
